# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("stock.csv",index_col=0,parse_dates=False)
#parse_dates 可为false

# %%
df.index
## dtype datatime64 当parse_dates=false是时间字段解析为字符串
# Out:
# Index(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05', '2018-01-08',
#        '2018-01-09', '2018-01-10', '2018-01-11', '2018-01-12', '2018-01-15',
#        ...
#        '2018-09-19', '2018-09-20', '2018-09-21', '2018-09-25', '2018-09-26',
#        '2018-09-27', '2018-09-28', '2018-10-08', '2018-10-09', '2018-10-10'],
#       dtype='object', name='Date', length=186)

# %%
df.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
df.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  186.000000  185.000000  185.000000  186.000000  1.860000e+02
# mean    17.850237   17.059405   17.445808   17.467266  2.397656e+07
# std      1.198530    1.129775    1.173615    1.190189  9.830443e+06
# min     15.471400   14.400000   14.857100   15.085700  0.000000e+00
# 25%     16.917500   16.260000   16.600000   16.608925  1.695616e+07
# 50%     17.680700   17.010000   17.400000   17.386450  2.151588e+07
# 75%     18.591075   17.809999   18.200001   18.160000  2.834116e+07
# max     21.035700   19.935699   20.557100   20.735701  5.718649e+07
#
#         Adj Close
# count  186.000000
# mean    17.421475
# std      1.184797
# min     15.000504
# 25%     16.550625
# 50%     17.379999
# 75%     18.160000
# max     20.618597

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186 entries, 2018-01-02 to 2018-10-10
# Data columns (total 6 columns):
# High         186 non-null float64
# Low          185 non-null float64
# Open         185 non-null float64
# Close        186 non-null float64
# Volume       186 non-null float64
# Adj Close    186 non-null float64
# dtypes: float64(6)
# memory usage: 10.2+ KB

# %%
df.shape
# Out:
# (186, 6)

# %%
df.head(3)
# Out:
#                High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  17.6714  16.214300  16.214300  17.671400  57186488.0  17.571602
# 2018-01-03  17.8857  17.378599  17.492901  17.578600  41095849.0  17.479324
# 2018-01-04  19.1429  17.864300  17.864300  18.871401  52611597.0  18.764826

# %%
df.tail(3)
# Out:
#              High    Low       Open  Close      Volume  Adj Close
# Date
# 2018-10-08  16.25  15.20  16.209999  15.28  27434576.0      15.28
# 2018-10-09  15.56  15.28  15.340000  15.35  13828463.0      15.35
# 2018-10-10  15.78  15.38  15.450000  15.43  13531576.0      15.43

# %%
df.loc[df.isnull().any(axis=1)]
#df.isnull().T.any()
# Out:
#                  High        Low   Open      Close      Volume  Adj Close
# Date
# 2018-06-14  17.219999  16.950001    NaN  17.030001   9183375.0  17.030001
# 2018-06-22  16.250000        NaN  15.83  16.200001  10595423.0  16.200001

# %%
# print(df.dropna(axis=0,how="any"))
# axis 按照哪一位维度删除
# how = any/all

# %%
# help(df.fillna)
# fillna 和正常理解的顺序不一致
df2 = df.fillna(method="ffill",axis="index")
print(df2.ix[["2018-06-13","2018-06-14","2018-06-21","2018-06-22"]])
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-06-13  17.500000  16.870001  17.500000  17.010000  14379846.0  17.010000
# 2018-06-14  17.219999  16.950001  17.500000  17.030001   9183375.0  17.030001
# 2018-06-21  16.620001  15.760000  16.379999  15.820000  12420409.0  15.820000
# 2018-06-22  16.250000  15.760000  15.830000  16.200001  10595423.0  16.200001
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
